# %%
from roboflow import Roboflow

rf = Roboflow(api_key="B1IovfYIG6d7q9rSBBG1")
project = rf.workspace().project(r"auto-time-classify")
model = project.version("4").model
# version.deploy("yolov8-cls","runs/classify/classifyv4-no-multiclass/weights/","best.pt")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import cv2
cap = cv2.VideoCapture(r"I:\Genshin utils app\auto-time\downloadedvideos\C3R1 Raiden ｜ 3.3 Spiral Abyss 12-3-1 Jadeplume Terrorshroom 10s.mp4")
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %%
job_id, signed_url, expire_time = model.predict(
    r"I:\Genshin utils app\auto-time\downloadedvideos\C3R1 Raiden ｜ 3.3 Spiral Abyss 12-3-1 Jadeplume Terrorshroom 10s.mp4",
    fps=fps,
    prediction_type="batch-video",
)
results = model.poll_until_video_results(job_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 job_id, signed_url, expire_time = model.predict_video(
#       2     r"I:\Genshin utils app\auto-time\downloadedvideos\C3R1 Raiden ｜ 3.3 Spiral Abyss 12-3-1 Jadeplume Terrorshroom 10s.mp4",
#       3     fps=fps,
#       4     prediction_type="batch-video",
#       5 )
#       6 results = model.poll_until_video_results(job_id)
#
# AttributeError: 'ClassificationModel' object has no attribute 'predict_video'
